# %% [markdown]
# <a href="https://colab.research.google.com/github/sohanjs111/robots-speed-model/blob/main/Regression_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle

# %% [markdown]
# # Import the datasets

# %%
evo = pd.read_csv('https://raw.githubusercontent.com/sohanjs111/robots-speed-model/main/Dataset/Evocortex.csv')
bot = pd.read_csv('https://raw.githubusercontent.com/sohanjs111/robots-speed-model/main/Dataset/Turtlebot3.csv')

# %% [markdown]
# ## For TurtleBot3

# %%
bot_x = bot.iloc[:, 0].values    # Speed
bot_y1 = bot.iloc[:, 1].values   # Green Carpet
bot_y2 = bot.iloc[:, 2].values   # Floor

# %%
bot_x = np.reshape(bot_x, (-1, 1))

# %% [markdown]
# ### Plots

# %%
plt.scatter(bot_x, bot_y1, color = 'red')
plt.title('Turtlebot3 for Green carpet')
plt.xlabel('Speed in m/s')
plt.ylabel('Standard Deviation')
plt.show()

# %%
plt.scatter(bot_x, bot_y2, color = 'red')
plt.title('Turtlebot3 for Floor')
plt.xlabel('Speed in m/s')
plt.ylabel('Standard Deviation')
plt.show()

# %% [markdown]
# ## Evocortex

# %%
evo_x = evo.iloc[:, 0].values    # Speed
evo_y1 = evo.iloc[:, 1].values   # Green Carpet
evo_y2 = evo.iloc[:, 2].values   # Floor
evo_y3 = evo.iloc[:, 3].values   # Foam

# %%
evo_x = np.reshape(evo_x, (-1, 1))

# %% [markdown]
# ### Plots

# %%
plt.scatter(evo_x, evo_y1, color = 'blue')
plt.title('Evocortex for Green carpet')
plt.xlabel('Speed in m/s')
plt.ylabel('Standard Deviation')
plt.show()

# %%
plt.scatter(evo_x, evo_y2, color = 'blue')
plt.title('Evocortex for floor')
plt.xlabel('Speed in m/s')
plt.ylabel('Standard Deviation')
plt.show()

# %%
plt.scatter(evo_x, evo_y3, color = 'blue')
plt.title('Evocortex for foam')
plt.xlabel('Speed in m/s')
plt.ylabel('Standard Deviation')
plt.show()

# %% [markdown]
# # TurtleBot3

# %% [markdown]
# ## Simple Linear Regression

# %% [markdown]
# ### models

# %%
from sklearn.linear_model import LinearRegression
bot_sr1 = LinearRegression()
bot_sr1.fit(bot_x, bot_y1)
# Out:
# LinearRegression()

# %%
bot_sr2 = LinearRegression()
bot_sr2.fit(bot_x, bot_y2)
# Out:
# LinearRegression()

# %% [markdown]
# ### Plots

# %%
plt.scatter(bot_x, bot_y1, color = 'red')
plt.plot(bot_x, bot_sr1.predict(bot_x), color = 'blue')
plt.title('Turtlebot3 for Green carpet')
plt.xlabel('Speed in m/s')
plt.ylabel('Standard Deviation')
plt.show()

# %%
plt.scatter(bot_x, bot_y2, color = 'red')
plt.plot(bot_x, bot_sr2.predict(bot_x), color = 'blue')
plt.title('Turtlebot3 for Floor')
plt.xlabel('Speed in m/s')
plt.ylabel('Standard Deviation')
plt.show()

# %% [markdown]
# ## Polynominal Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
bot_preg1 = PolynomialFeatures(degree = 3)
bot_pr1 = bot_preg1.fit_transform(bot_x)
bot_sreg1 = LinearRegression()
bot_sreg1.fit(bot_pr1, bot_y1)
# Out:
# LinearRegression()

# %%
bot_preg2 = PolynomialFeatures(degree = 4)
bot_pr2 = bot_preg2.fit_transform(bot_x)
bot_sreg2 = LinearRegression()
bot_sreg2.fit(bot_pr2, bot_y2)
# Out:
# LinearRegression()

# %%
plt.scatter(bot_x, bot_y1, color = 'red')
plt.plot(bot_x, bot_sreg1.predict(bot_preg1.fit_transform(bot_x)), color = 'blue')
plt.title('Turtlebot3 for Green carpet')
plt.xlabel('Speed in m/s')
plt.ylabel('Standard Deviation')
plt.show()

# %%
plt.scatter(bot_x, bot_y2, color = 'red')
plt.plot(bot_x, bot_sreg2.predict(bot_preg2.fit_transform(bot_x)), color = 'blue')
plt.title('Turtlebot3 for floor')
plt.xlabel('Speed in m/s')
plt.ylabel('Standard Deviation')
plt.show()

# %% [markdown]
# # Evocortex

# %% [markdown]
# # Simple regression

# %% [markdown]
# ### Models

# %%
from sklearn.linear_model import LinearRegression
evo_sr1 = LinearRegression()
evo_sr1.fit(evo_x, evo_y1)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
evo_sr2 = LinearRegression()
evo_sr2.fit(evo_x, evo_y2)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
evo_sr3 = LinearRegression()
evo_sr3.fit(evo_x, evo_y3)
# Out:
# LinearRegression()

# %% [markdown]
# ### Plots

# %%
plt.scatter(evo_x, evo_y1, color = 'red')
plt.plot(evo_x, evo_sr1.predict(evo_x), color = 'blue')
plt.title('Evocortex for Green carpet')
plt.xlabel('Speed in m/s')
plt.ylabel('Standard Deviation')
plt.show()

# %%
plt.scatter(evo_x, evo_y2, color = 'red')
plt.plot(evo_x, evo_sr2.predict(evo_x), color = 'blue')
plt.title('Evocortex for floor')
plt.xlabel('Speed in m/s')
plt.ylabel('Standard Deviation')
plt.show()

# %%
plt.scatter(evo_x, evo_y3, color = 'red')
plt.plot(evo_x, evo_sr3.predict(evo_x), color = 'blue')
plt.title('Evocortex for Foam')
plt.xlabel('Speed in m/s')
plt.ylabel('Standard Deviation')
plt.show()

# %% [markdown]
# ## Polynomial Models

# %% [markdown]
# ### Models

# %%
evo_preg1 = PolynomialFeatures(degree = 2)
evo_pr1 = evo_preg1.fit_transform(evo_x)
evo_sreg1 = LinearRegression()
evo_sreg1.fit(evo_pr1, evo_y1)
# Out:
# LinearRegression()

# %%
evo_preg2 = PolynomialFeatures(degree = 2)
evo_pr2 = evo_preg2.fit_transform(evo_x)
evo_sreg2 = LinearRegression()
evo_sreg2.fit(evo_pr2, evo_y2)
# Out:
# LinearRegression()

# %%
evo_preg3 = PolynomialFeatures(degree = 2)
evo_pr3 = evo_preg3.fit_transform(evo_x)
evo_sreg3 = LinearRegression()
evo_sreg3.fit(evo_pr3, evo_y3)
# Out:
# LinearRegression()

# %% [markdown]
# ### Plots

# %%
plt.scatter(evo_x, evo_y1, color = 'red')
plt.plot(evo_x, evo_sreg1.predict(evo_preg1.fit_transform(evo_x)), color = 'blue')
plt.title('Evocortex for Green Carpet')
plt.xlabel('Speed in m/s')
plt.ylabel('Standard Deviation')
plt.show()

# %%
plt.scatter(evo_x, evo_y2, color = 'red')
plt.plot(evo_x, evo_sreg2.predict(evo_preg2.fit_transform(evo_x)), color = 'blue')
plt.title('Evocortex for Floor')
plt.xlabel('Speed in m/s')
plt.ylabel('Standard Deviation')
plt.show()

# %%
plt.scatter(evo_x, evo_y3, color = 'red')
plt.plot(evo_x, evo_sreg3.predict(evo_preg3.fit_transform(evo_x)), color = 'blue')
plt.title('Evocortex for Foam')
plt.xlabel('Speed in m/s')
plt.ylabel('Standard Deviation')
plt.show()

# %% [markdown]
# # Download the models

# %%
bot_sr_y1 = 'bot_sr_y1.sav'
bot_sr_y2 = 'bot_sr_y2.sav'
bot_poly_y1 = 'bot_poly_y1.sav'
bot_poly_y2 = 'bot_poly_y2.sav'
evo_sr_y1 = 'evo_sr_y1.sav'
evo_sr_y2 = 'evo_sr_y2.sav'
evo_sr_y3 = 'evo_sr_y3.sav'
evo_poly_y1 = 'evo_poly_y1.sav'
evo_poly_y2 = 'evo_poly_y2.sav'
evo_poly_y3 = 'evo_poly_y3.sav'

# %%
pickle.dump(bot_sr1, open(bot_sr_y1, 'wb'))
pickle.dump(bot_sr2, open(bot_sr_y2, 'wb'))
pickle.dump(bot_sreg1, open(bot_poly_y1, 'wb'))
pickle.dump(bot_sreg2, open(bot_poly_y2, 'wb'))
pickle.dump(evo_sr1, open(evo_sr_y1, 'wb'))
pickle.dump(evo_sr2, open(evo_sr_y2, 'wb'))
pickle.dump(evo_sr3, open(evo_sr_y3, 'wb'))
pickle.dump(evo_sreg1, open(evo_poly_y1, 'wb'))
pickle.dump(evo_sreg2, open(evo_poly_y2, 'wb'))
pickle.dump(evo_sreg3, open(evo_poly_y3, 'wb'))
